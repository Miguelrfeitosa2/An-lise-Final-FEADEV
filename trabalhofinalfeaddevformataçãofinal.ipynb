# %%
'''
# !pip install selenium
# !pip install bs4
#Webdriver do navegador para o caminho do Python, mudar no código de acordo com o navegador
'''
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests as rs
import time
'''
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.edge import options
from selenium.webdriver.edge.options import Options
'''
# Out:
# '\nfrom bs4 import BeautifulSoup\nfrom selenium import webdriver\nfrom selenium.webdriver.common.by import By\nfrom selenium.webdriver.edge import options\nfrom selenium.webdriver.edge.options import Options\n'

# %%
'''
options = Options()
options.headless = False
navegador = webdriver.Edge()
nav = navegador.get("https://pesquisascnc.com.br/")
time.sleep(3)
navegador.find_element(by = By.XPATH, value = '/html/body/div[1]/nav/div/div[3]/button[1]').click()

inputuser = navegador.find_element(by = By.ID, value = 'log')
inputuser.send_keys('Miguel.feitosa@usp.br')
inputsenha = navegador.find_element(by = By.ID, value = 'pwd')
inputsenha.send_keys('Miguel007')
navegador.find_element(by = By.XPATH, value = '/html/body/div[3]/div/div/div[2]/div/div[2]/div[1]/button').click()
navegador.find_element(by = By.XPATH, value = '//*[@id="owl-demo"]/div[1]/div/div[3]/div/div/div[1]/a').click()
navegador.find_element(by = By.XPATH, value = '/html/body/div[2]/footer/div[2]/ul/li[3]/a').click()

time.sleep(3)

req = rs.get(nav)
site = BeautifulSoup(req.text, "html.parser")
tabelinha = site.find("table")
print(tabelinha[0])

tabela = navegador.find_element(by = By.XPATH, value = '/html/body/div[1]/div/div/table/tbody/tr[4]/td[2]')
soup = BeautifulSoup(conteúdotabela, "html.parser")
print(soup)

req = rs.get('https://pesquisascnc.com.br/pesquisa-peic/')
site = BeautifulSoup(req.text, "html.parser")
tabelinha = site.find("table")
print(tabelinha[0])
'''
# Out:
# '\noptions = Options()\noptions.headless = False\nnavegador = webdriver.Edge()\nnav = navegador.get("https://pesquisascnc.com.br/")\ntime.sleep(3)\nnavegador.find_element(by = By.XPATH, value = \'/html/body/div[1]/nav/div/div[3]/button[1]\').click()\n\ninputuser = navegador.find_element(by = By.ID, value = \'log\')\ninputuser.send_keys(\'Miguel.feitosa@usp.br\')\ninputsenha = navegador.find_element(by = By.ID, value = \'pwd\')\ninputsenha.send_keys(\'Miguel007\')\nnavegador.find_element(by = By.XPATH, value = \'/html/body/div[3]/div/div/div[2]/div/div[2]/div[1]/button\').click()\nnavegador.find_element(by = By.XPATH, value = \'//*[@id="owl-demo"]/div[1]/div/div[3]/div/div/div[1]/a\').click()\nnavegador.find_element(by = By.XPATH, value = \'/html/body/div[2]/footer/div[2]/ul/li[3]/a\').click()\n\ntime.sleep(3)\n\nreq = rs.get(nav)\nsite = BeautifulSoup(req.text, "html.parser")\ntabelinha = site.find("table")\nprint(tabelinha[0])\n\ntabela = navegador.find_element(by = By.XPATH, value 
# ...

# %%
df_inadimplência = pd.read_excel('inadimplência.xlsx').dropna()
df_setores = pd.read_excel('inadimplência.xlsx', sheet_name = 'Setores').dropna()
df_AC = pd.read_excel('inadimplência.xlsx', sheet_name = 'AC').dropna()
df_AL = pd.read_excel('inadimplência.xlsx', sheet_name = 'AL').dropna()
df_AM = pd.read_excel('inadimplência.xlsx', sheet_name = 'AM').dropna()
df_AP = pd.read_excel('inadimplência.xlsx', sheet_name = 'AP').dropna()
df_BA = pd.read_excel('inadimplência.xlsx', sheet_name = 'BA').dropna()
df_CE = pd.read_excel('inadimplência.xlsx', sheet_name = 'CE').dropna()
df_DF = pd.read_excel('inadimplência.xlsx', sheet_name = 'DF').dropna()
df_ES = pd.read_excel('inadimplência.xlsx', sheet_name = 'ES').dropna()
df_GO = pd.read_excel('inadimplência.xlsx', sheet_name = 'GO').dropna()
df_MA = pd.read_excel('inadimplência.xlsx', sheet_name = 'MA').dropna()
df_MG = pd.read_excel('inadimplência.xlsx', sheet_name = 'MG').dropna()
df_MS = pd.read_excel('inadimplência.xlsx', sheet_name = 'MS').dropna()
df_MT = pd.read_excel('inadimplência.xlsx', sheet_name = 'MT').dropna()
df_PA = pd.read_excel('inadimplência.xlsx', sheet_name = 'PA').dropna()
df_PB = pd.read_excel('inadimplência.xlsx', sheet_name = 'PB').dropna()
df_PE = pd.read_excel('inadimplência.xlsx', sheet_name = 'PE').dropna()
df_PI = pd.read_excel('inadimplência.xlsx', sheet_name = 'PI').dropna()
df_PR = pd.read_excel('inadimplência.xlsx', sheet_name = 'PR').dropna()
df_RJ = pd.read_excel('inadimplência.xlsx', sheet_name = 'RJ').dropna()
df_RN = pd.read_excel('inadimplência.xlsx', sheet_name = 'RN').dropna()
df_RO = pd.read_excel('inadimplência.xlsx', sheet_name = 'RO').dropna()
df_RR = pd.read_excel('inadimplência.xlsx', sheet_name = 'RR').dropna()
df_RS = pd.read_excel('inadimplência.xlsx', sheet_name = 'RS').dropna()
df_SC = pd.read_excel('inadimplência.xlsx', sheet_name = 'SC').dropna()
df_SE = pd.read_excel('inadimplência.xlsx', sheet_name = 'SE').dropna()
df_SP = pd.read_excel('inadimplência.xlsx', sheet_name = 'SP').dropna()
df_TO = pd.read_excel('inadimplência.xlsx', sheet_name = 'TO').dropna()

df_setores["Utilities II"] = df_setores["Bancos / Cartões (A)"] + df_setores["Utilities (B)"] + df_setores["Varejo (D)"]
df_setores["Não Utilitários"] = df_setores["Serviços (E)"] + df_setores["Financeiras (F)"] + df_setores["Outros (H)"]+ df_setores["Telefonia (C)"] + df_setores["Securitizadoras (G)"]

# %%
E = df_AC['Dívida Média                 (por CPF)'].mean()*1000
E1 = df_AL['Dívida Média                 (por CPF)'].mean()*1000
E2 = df_AM['Dívida Média                 (por CPF)'].mean()*1000
E3 = df_AP['Dívida Média                 (por CPF)'].mean()*1000
E4 = df_BA['Dívida Média                 (por CPF)'].mean()*1000
E5 = df_CE['Dívida Média                 (por CPF)'].mean()*1000
E6 = df_DF['Dívida Média                 (por CPF)'].mean()*1000
E7 = df_ES['Dívida Média                 (por CPF)'].mean()*1000
E10 = df_GO['Dívida Média                 (por CPF)'].mean()*1000
E11 = df_MA['Dívida Média                 (por CPF)'].mean()*1000
E12= df_MG['Dívida Média                 (por CPF)'].mean()*1000
E13 = df_MS['Dívida Média                 (por CPF)'].mean()*1000
E14= df_MT['Dívida Média                 (por CPF)'].mean()*1000
E15= df_PA['Dívida Média                 (por CPF)'].mean()*1000
E16= df_PB['Dívida Média                 (por CPF)'].mean()*1000
E17 = df_PE['Dívida Média                 (por CPF)'].mean()*1000
E18= df_PI['Dívida Média                 (por CPF)'].mean()*1000
E19 = df_PR['Dívida Média                 (por CPF)'].mean()*1000
E20 = df_RJ['Dívida Média                 (por CPF)'].mean()*1000
E21 = df_RN['Dívida Média                 (por CPF)'].mean()*1000
E22 = df_RO['Dívida Média                 (por CPF)'].mean()*1000
E23 = df_RR['Dívida Média                 (por CPF)'].mean()*1000
E24 = df_RS['Dívida Média                 (por CPF)'].mean()*1000
E25 = df_SE['Dívida Média                 (por CPF)'].mean()*1000
E26 = df_SP['Dívida Média                 (por CPF)'].mean()*1000
E27 = df_TO['Dívida Média                 (por CPF)'].mean()*1000
Média_dívida = [E, E1, E2, E3, E4, E5, E6, E7, E10, E11, E12, E13, E14, E15, E16, E17, E18, E19, E20, E21, E22, E23, E24, E25, E26, E27]
Estados_inad = ['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG', 'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR', 'RS', 'SE', 'SP', 'TO']
Ordem = Média_dívida.sort()
j = len(Média_dívida)

posição_Q1 = j*(25/100)
posição_Q2 = j*(50/100)
posição_Q3 = j*(75/100)
##print(Q1)
##print(Q3)


NúmeroQ1 = Média_dívida[6]
NúmeroQ3 = Média_dívida[19]
Qinterquartil = NúmeroQ3 - NúmeroQ1
Limitesup = NúmeroQ3 + (15/10)* Qinterquartil
Limiteinf = NúmeroQ1 - (15/10)* Qinterquartil

plt.figure(figsize=(10,4))
plt.bar(Estados_inad, Média_dívida)
plt.xlabel("Estados Brasileiros")
plt.ylabel("Média da dívida (em milhares)")
plt.title("Média da Dívida por CPF nos Estados")
plt.axhline(Limitesup, 0, 1, color = 'r', **{'ls':'-.','lw': 1})
plt.axhline(Limiteinf, 0, 1, color = 'r', **{'ls':'-.','lw': 1})
plt.text(1, 5300, Limitesup)
plt.text(1, 1500, Limiteinf)

plt.show()

'''
plt.boxplot(Média_dívida, vert = 0, patch_artist = False)
plt.xlabel("Estados Brasileiros")
plt.ylabel("Média da dívida (em milhares)")
plt.title("Média da Dívida por CPF nos Estados")
plt.show()
'''
# Out:
# '\nplt.boxplot(Média_dívida, vert = 0, patch_artist = False)\nplt.xlabel("Estados Brasileiros")\nplt.ylabel("Média da dívida (em milhares)")\nplt.title("Média da Dívida por CPF nos Estados")\nplt.show()\n'

# %%
E = df_AC['Consumidores Inadimplentes'].mean()
E1 = df_AL['Consumidores Inadimplentes'].mean()
E2 = df_AM['Consumidores Inadimplentes'].mean()
E3 = df_AP['Consumidores Inadimplentes'].mean()
E4 = df_BA['Consumidores Inadimplentes'].mean()
E5 = df_CE['Consumidores Inadimplentes'].mean()
E6 = df_DF['Consumidores Inadimplentes'].mean()
E7 = df_ES['Consumidores Inadimplentes'].mean()
E10 = df_GO['Consumidores Inadimplentes'].mean()
E11 = df_MA['Consumidores Inadimplentes'].mean()
E12= df_MG['Consumidores Inadimplentes'].mean()
E13 = df_MS['Consumidores Inadimplentes'].mean()
E14= df_MT['Consumidores Inadimplentes'].mean()
E15= df_PA['Consumidores Inadimplentes'].mean()
E16= df_PB['Consumidores Inadimplentes'].mean()
E17 = df_PE['Consumidores Inadimplentes'].mean()
E18= df_PI['Consumidores Inadimplentes'].mean()
E19 = df_PR['Consumidores Inadimplentes'].mean()
E20 = df_RJ['Consumidores Inadimplentes'].mean()
E21 = df_RN['Consumidores Inadimplentes'].mean()
E22 = df_RO['Consumidores Inadimplentes'].mean()
E23 = df_RR['Consumidores Inadimplentes'].mean()
E24 = df_RS['Consumidores Inadimplentes'].mean()
E25 = df_SE['Consumidores Inadimplentes'].mean()
E26 = df_SP['Consumidores Inadimplentes'].mean()
E27 = df_TO['Consumidores Inadimplentes'].mean()

Média_cons = [E, E1, E2, E3, E4, E5, E6, E7, E10, E11, E12, E13, E14, E15, E16, E17, E18, E19, E20, E21, E22, E23, E24, E25, E26, E27]
Estados_inad = ['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG', 'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR', 'RS', 'SE', 'SP', 'TO']
#Pode estar enviesado pelo número de habitantes de cada Estado. Como anular?

plt.figure(figsize=(10,4))
plt.bar(Estados_inad, Média_cons)
plt.xlabel("Estados Brasileiros")
plt.ylabel("Média da dívida (em milhares)")
plt.title("Média da Quantidade de Consumidores Inadimplentes")
plt.show()

# %%
m = df_setores['Bancos / Cartões (A)'].mean()*100
m1 = df_setores['Utilities (B)'].mean()*100
m2 = df_setores['Telefonia (C)'].mean()*100
m3 =df_setores['Varejo (D)'].mean()*100
m4 = df_setores['Serviços (E)'].mean()*100
m5 = df_setores['Financeiras (F)'].mean()*100
m6 = df_setores['Securitizadoras (G)'].mean()*100
m7 = df_setores['Outros (H)'].mean()*100
médias = [m, m1, m2, m3, m4, m5, m6, m7]
setores = ['Bancos / Cartões','Utilities','Telefonia', 'Varejo', 'Serviços', 'Financeiras', 'Securitizadoras', 'Outros' ]
plt.figure(figsize = (15, 4))
plt.bar(setores, médias)
plt.xlabel("Setores de Dívidas")
plt.ylabel("Médias de Endividamento por setor em %")
plt.title("Setores de Endividamento da População Brasileira")
plt.show()

display(df_setores)
# Out:
#           Mês  Bancos / Cartões (A)  Utilities (B)  Telefonia (C)  Varejo (D)  \
# 0  2018-01-01              0.281830       0.189428       0.118731    0.132873
# 1  2018-02-01              0.283481       0.191028       0.119126    0.132721
# 2  2018-03-01              0.280965       0.190363       0.117085    0.131686
# 3  2018-04-01              0.281746       0.190480       0.115231    0.130106
# 4  2018-05-01              0.280916       0.192093       0.115579    0.131355
# ..        ...                   ...            ...            ...         ...
# 70 2023-11-01              0.289702       0.233754       0.045752    0.111370
# 71 2023-12-01              0.279208       0.240369       0.045460    0.110715
# 72 2024-01-01              0.293725       0.230875       0.044822    0.109511
# 73 2024-02-01              0.292742       0.226699       0.044678    0.109850
# 74 2024-03-01              0.293383       0.229859       0.044246    0.104961
#
# ...

# %%
mm = df_setores['Utilities II'].mean()
mm1 = df_setores['Não Utilitários'].mean()
Setores_EssenciaiseNãoEssenciais_comparados = ['Utilities II', 'Não Utilitários']
MédiaSetores_EssenciaiseNãoEssenciais_comparados = [mm, mm1]
plt.figure(figsize = (15, 4))
plt.pie(MédiaSetores_EssenciaiseNãoEssenciais_comparados, labels = Setores_EssenciaiseNãoEssenciais_comparados, autopct = "%.2f%%", startangle = 90, explode = (0.02, 0.02 ))
plt.show()

# %%
display(df_inadimplência)
plt.figure(figsize = (10,4))
plt.plot(df_inadimplência['Mês'], df_inadimplência['% da População Adulta.1'])
plt.xlabel("Período")
plt.ylabel("% de Inadimplentes no Brasil")
plt.title("Inadimplentes")
plt.grid()
plt.show()
# Out:
#           Mês Consumidores Inadimplentes (milhões)  \
# 10 2016-11-01                               59.344
# 11 2016-12-01                               58.976
# 12 2017-01-01                               59.022
# 13 2017-02-01                               59.119
# 14 2017-03-01                                59.12
# ..        ...                                  ...
# 94 2023-11-01                             71.80892
# 95 2023-12-01                            71.102439
# 96 2024-01-01                            72.069816
# 97 2024-02-01                            72.039263
# 98 2024-03-01                            72.894821
#
#    Dívidas Negativadas (milhões) Dívidas Negativadas          (R$ bilhões)  \
# 10                       228.652                                229.540934
# 11                        229.45                                228.340409
# 12                       227.612                                229.120895
# ...

# %%
IPCA = pd.read_excel('inflaçãodados.xlsx').tail(180)
plt.figure(figsize=(10,4))
plt.plot(IPCA[    'mês/Ano'], IPCA['Var. % mensal'])
plt.xlabel("Ano")
plt.ylabel("Taxa de Inflação")
plt.title("Histórico IPCA")
plt.grid()
plt.show()

# %%
txdesemprego = pd.read_excel('20240702013148.xlsx').drop("Unnamed: 1", axis = 1)
plt.figure(figsize = (10, 4))
plt.plot(txdesemprego['Data'],txdesemprego['Taxa de Desemprego'])
plt.xlabel("Data")
plt.ylabel("Taxa de Desemprego em %")
plt.title('Histórico Taxa de Desemprego')
plt.grid()
plt.show()

# %%
Rendamédia = pd.read_excel('20240702030548.xlsx').drop("Unnamed: 1", axis = 1)
plt.figure(figsize=(10,4))
plt.tight_layout()
plt.plot(Rendamédia['Data'], Rendamédia['Rendimento Médio'])
plt.xlabel("Data")
plt.ylabel("Rendimento Médio")
plt.ylim(2600, 3400)
plt.title('Histórico do Rendimento Médio')
plt.grid()

# %%
Endividamento = pd.read_excel('endividadostab.xlsx')
display(Endividamento)
plt.figure(figsize=(10,4))
plt.plot(Endividamento['MESES'], Endividamento['ENDIVIDADOS'])
plt.xlabel('Período')
plt.ylabel('% de Endividados')
plt.title("Taxa de Endividamento da População")
plt.grid()
plt.show()
# Out:
#          MESES  ENDIVIDADOS  CONTAS EM ATRASO  NÃO TERÃO CONDIÇÕES DE PAGAR  \
# 0   2010-01-01         61.2              29.8                           9.9
# 1   2010-02-01         61.8              25.6                           8.6
# 2   2010-03-01         63.0              27.3                           8.7
# 3   2010-04-01         58.0              24.4                           9.0
# 4   2010-05-01         58.7              25.1                           8.5
# ..         ...          ...               ...                           ...
# 169 2024-02-01         77.9              28.1                          11.9
# 170 2024-03-01         78.1              28.6                          12.0
# 171 2024-04-01         78.5              28.6                          12.1
# 172 2024-05-01         78.8              28.6                          12.0
# 173 2024-06-01         78.8              28.8                          12.0
#
# ...

# %%
Selic = pd.read_excel("Selichistórico.xlsx")
plt.figure(figsize =(10,4))
plt.plot(Selic['Período'], Selic['Taxa ']*100)
plt.xlabel("Período")
plt.ylabel("Taxa Selic em %")
plt.title("Histórico da Taxa Selic")
plt.grid()
plt.show()

# %%
#gráfico para análise de setores e de utilities e utilitários
plt.figure(figsize = (10,4))
plt.plot(df_setores['Mês'], df_setores['Bancos / Cartões (A)']*100, label = 'Bancos/Cartões')
plt.plot(df_setores['Mês'], df_setores['Utilities (B)']*100, label = 'Utilities')
plt.plot(df_setores['Mês'], df_setores['Telefonia (C)']*100, label = 'Telefonia')
plt.plot(df_setores['Mês'], df_setores['Varejo (D)']*100, label = 'Varejo')
plt.plot(df_setores['Mês'], df_setores['Serviços (E)']*100, label = 'Serviços')
plt.plot(df_setores['Mês'], df_setores['Financeiras (F)']*100, label = 'Financeiras')
plt.plot(df_setores['Mês'], df_setores['Securitizadoras (G)']*100, label = 'Securitizadoras')
plt.plot(df_setores['Mês'], df_setores['Outros (H)']*100, label = 'Outros')
plt.xlabel('Período')
plt.ylabel('% do Setor')
plt.ylim(0, 35)
plt.grid()
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.title("Setores de Endividamento")
plt.show()

# %%
plt.figure(figsize = (10,4))
plt.plot(df_setores['Mês'], df_setores['Utilities II']*100, label = 'Essenciais')
plt.plot(df_setores['Mês'], df_setores['Não Utilitários']*100, label = 'Não Essenciais')
plt.xlabel('Período')
plt.ylabel('% do Setor')
plt.title("Setor Essencial x Não Essencial")
plt.ylim(34, 66)
plt.legend()
plt.grid()
plt.show()

# %%
# visualização em barras horizontais dos setores
plt.barh(df_setores['Mês'], df_setores['Bancos / Cartões (A)']*100, label = 'Bancos/Cartões')
plt.barh(df_setores['Mês'], df_setores['Utilities (B)']*100, label = 'Utilities')
plt.barh(df_setores['Mês'], df_setores['Telefonia (C)']*100, label = 'Telefonia')
plt.barh(df_setores['Mês'], df_setores['Varejo (D)']*100, label = 'Varejo')
plt.barh(df_setores['Mês'], df_setores['Serviços (E)']*100, label = 'Serviços')
plt.barh(df_setores['Mês'], df_setores['Financeiras (F)']*100, label = 'Financeiras')
plt.barh(df_setores['Mês'], df_setores['Securitizadoras (G)']*100, label = 'Securitizadoras')
plt.barh(df_setores['Mês'], df_setores['Outros (H)']*100, label = 'Outros')
plt.xlabel('% dos Setores')
plt.ylabel('Período')
plt.grid()
plt.legend()
plt.title("Setores de Endividamento")
plt.show()

# %%
#Análise para a H0; endividamento, inadimplência, taxa de desemprego e renda média
fig,ax = plt.subplots()
ax.set_xlabel("Período")
ax.set_ylabel("Taxa")
ax.plot(df_inadimplência['Mês'].head(200), df_inadimplência['% da População Adulta.1'].head(200), label = '% Inadimplência', color = 'tomato')
ax.plot(txdesemprego['Data'],txdesemprego['Taxa de Desemprego'], label = '% Desemprego', color = 'black')
ax.plot(Endividamento['MESES'], Endividamento['ENDIVIDADOS'], label = '% Endividamento')
plt.ylim(0,80)
plt.legend(loc='upper left', bbox_to_anchor=(1.1,0.9199))
ax2 = ax.twinx()
#ax2.ylabel('Valor Renda Média')
ax2.plot(Rendamédia['Data'], Rendamédia['Rendimento Médio'], label = 'Valor Renda Médio', color = 'yellow')

plt.legend(loc='upper left', bbox_to_anchor=(1.1,1))
plt.grid()
plt.show()

'''
#plt.axvline(15, 0, 1, color = 'b', **{'ls': '-.', 'lw':: 5})
'''
# Out:
# "\n#plt.axvline(15, 0, 1, color = 'b', **{'ls': '-.', 'lw':: 5})\n"

# %%
#Análise para H1; inadimplência, endividamento, selic, ipca
fig,ax = plt.subplots()
ax.set_xlabel("Período")
ax.set_ylabel("Taxa")
ax.plot(df_inadimplência['Mês'], df_inadimplência['% da População Adulta.1'], label = '% Inadimplência', color = 'tomato')
ax.plot(Endividamento['MESES'], Endividamento['ENDIVIDADOS'], label = '% Endividamento', color = 'black')
plt.ylim(30, 80)
plt.legend(loc='upper left', bbox_to_anchor=(1.1,0.899))

ax2 = ax.twinx()
ax2.plot(IPCA[    'mês/Ano'], IPCA['Var. % mensal'], label = '% IPCA')
ax2.plot(Selic['Período'], Selic['Taxa ']*100, label = '% Selic ')
plt.ylim(-1, 15)
plt.legend(loc='upper left', bbox_to_anchor=(1.1, 1.03))
'''
#plt.axvline(15, 0, 1, color = 'b', **{'ls': '-.', 'lw':: 5})
'''
plt.grid()
plt.show()
plt.grid()
plt.show()

# %%
#Traço da linha para comparar IPCA e Selic - H1
Selic = pd.read_excel("Selichistórico.xlsx")
plt.figure(figsize =(10,4))
plt.plot(Selic['Período'], Selic['Taxa ']*100)
plt.xlabel("Período")
plt.ylabel("Taxa Selic em %")
plt.title("Histórico da Taxa Selic")
plt.grid()
plt.show()

IPCA = pd.read_excel('inflaçãodados.xlsx').tail(180)
plt.figure(figsize=(10,4))
plt.plot(IPCA[    'mês/Ano'], IPCA['Var. % mensal'])
plt.xlabel("Ano")
plt.ylabel("Taxa de Inflação")
plt.title("Histórico IPCA")
plt.grid()
plt.show()

# %%
#Traço da linha para comparar Inadimplência e Endividamento - H1
plt.figure(figsize = (10,4))
plt.plot(df_inadimplência['Mês'], df_inadimplência['% da População Adulta.1'])
plt.xlabel("Período")
plt.ylabel("% de Inadimplentes no Brasil")
plt.title("Inadimplentes")
plt.grid()
plt.show()

Endividamento = pd.read_excel('endividadostab.xlsx')
plt.figure(figsize=(10,4))
plt.plot(Endividamento['MESES'], Endividamento['ENDIVIDADOS'])
plt.xlabel('Período')
plt.ylabel('% de Endividados')
plt.title("Taxa de Endividamento da População")
plt.grid()
plt.show()

# %%
#Traçar linhas para endividamento, inadimplência, taxa de desemprego e rendimento médio - H0 
plt.figure(figsize = (10,4))
plt.plot(df_inadimplência['Mês'], df_inadimplência['% da População Adulta.1'])
plt.xlabel("Período")
plt.ylabel("% de Inadimplentes no Brasil")
plt.title("Inadimplentes")
plt.grid()
plt.show()

Endividamento = pd.read_excel('endividadostab.xlsx')
plt.figure(figsize=(10,4))
plt.plot(Endividamento['MESES'], Endividamento['ENDIVIDADOS'])
plt.xlabel('Período')
plt.ylabel('% de Endividados')
plt.title("Taxa de Endividamento da População")
plt.grid()
plt.show()

txdesemprego = pd.read_excel('20240702013148.xlsx').drop("Unnamed: 1", axis = 1)
plt.figure(figsize = (10, 4))
plt.plot(txdesemprego['Data'],txdesemprego['Taxa de Desemprego'])
plt.xlabel("Data")
plt.ylabel("Taxa de Desemprego em %")
plt.title('Histórico Taxa de Desemprego')
plt.grid()
plt.show()

Rendamédia = pd.read_excel('20240702030548.xlsx').drop("Unnamed: 1", axis = 1)
plt.figure(figsize=(10,4))
plt.tight_layout()
plt.plot(Rendamédia['Data'], Rendamédia['Rendimento Médio'])
plt.xlabel("Data")
plt.ylabel("Rendimento Médio")
plt.ylim(2600, 3400)
plt.title('Histórico do Rendimento Médio')
plt.grid()
